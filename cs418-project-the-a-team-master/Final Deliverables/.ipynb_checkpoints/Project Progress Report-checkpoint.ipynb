# %% [markdown]
# # Project Introduction

# %% [markdown]
# Data we are analyzing:
# 1. 500 Cities: Local Data for Better Health from data.gov website. This dataset includes 2016, 2015 model-based small area estimates for 27 measures of chronic disease related to unhealthy behaviors (5), health outcomes (13), and use of preventive services (9). Data were provided by the Centers for Disease Control and Prevention (CDC), Division of Population Health, Epidemiology and Surveillance Branch. Link to download the dataset is:
# https://chronicdata.cdc.gov/api/views/6vp6-wxuq/rows.csv?accessType=DOWNLOAD
# 2. Timely and Effective Care measures - provider data from data.gov website. This data set includes provider-level data for measures of cataract surgery outcome, colonoscopy follow-up, heart attack care, etc. Link to download the dataset is:
# https://data.medicare.gov/api/views/yv7e-xc69/rows.csv?accessType=DOWNLOAD
#
# Question(s) we are investigating:
#
# 1. How are various Unhealthy behaviours related to Health Outcomes?
# 2. Are there enough speciality hospitals to treat chronic diseases?
# 3. How is Per capita income of the state related to Timely and Effective Care measures provided by hospitals?

# %% [markdown]
# # Any Changes

# %% [markdown]
# We aimed to also consider Environmental factors as a catalyst along with Unhealthy Behaviours and Income to predict various Health Outcomes for different geographic locations across the States. However, after doing several analysis and EDA, now we're more focused on considering Unhealthy Behaviours and Income.
#
# Addition: Included the hospital dataset for analysing the location of hospitals and it's services for specific geographical locations.

# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore

# %matplotlib inline

# %%
df = pd.read_csv('500_Cities__Local_Data_for_Better_Health__2018_release.zip')

# %%
df.info(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 810103 entries, 0 to 810102
# Data columns (total 24 columns):
# Year                          810103 non-null int64
# StateAbbr                     810103 non-null object
# StateDesc                     810103 non-null object
# CityName                      810047 non-null object
# GeographicLevel               810103 non-null object
# DataSource                    810103 non-null object
# Category                      810103 non-null object
# UniqueID                      810103 non-null object
# Measure                       810103 non-null object
# Data_Value_Unit               810103 non-null object
# DataValueTypeID               810103 non-null object
# Data_Value_Type               810103 non-null object
# Data_Value                    787311 non-null float64
# Low_Confidence_Limit          787311 non-null float64
# High_Confidence_Limit         787311 non-null float64
# Data_Value_Footnote_Symbol    22794 non-null object
# Data_Value_Footnote           22794 non-null object
# PopulationCount               810103 non-null int64
# GeoLocation                   810047 non-null object
# CategoryID                    810103 non-null object
# MeasureId                     810103 non-null object
# CityFIPS                      810047 non-null float64
# TractFIPS                     782047 non-null float64
# Short_Question_Text           810103 non-null object
# dtypes: float64(5), int64(2), object(17)
# memory usage: 148.3+ MB

# %%
# we only need non-adusted numbers, and only for cities not electoral areas
health = df[(df.Data_Value_Type=='Crude prevalence') & 
                    (df.GeographicLevel.isin(['City','US'])) ]
health.head(3)
# Out:
#    Year StateAbbr      StateDesc CityName GeographicLevel DataSource  \
# 1  2016        US  United States      NaN              US      BRFSS
# 3  2016        US  United States      NaN              US      BRFSS
# 5  2016        US  United States      NaN              US      BRFSS
#
#               Category UniqueID  \
# 1           Prevention       59
# 3      Health Outcomes       59
# 5  Unhealthy Behaviors       59
#
#                                              Measure Data_Value_Unit  ...  \
# 1  Current lack of health insurance among adults ...               %  ...
# 3             Arthritis among adults aged >=18 Years               %  ...
# 5        Binge drinking among adults aged >=18 Years               %  ...
#
#   High_Confidence_Limit Data_Value_Footnote_Symbol  Data_Value_Footnote  \
# 1                  11.8                        NaN                  NaN
# 3                  25.6                        NaN                  NaN
# 5                  17.2                        NaN                  NaN
#
#    PopulationCount  GeoLocation CategoryID  MeasureId  CityFIPS TractFIPS  \
# 1        308745538          NaN    PREVENT    ACCESS2       NaN       NaN
# 3        308745538          NaN    HLTHOUT  ARTHRITIS       NaN       NaN
# 5        308745538          NaN     UNHBEH      BINGE       NaN       NaN
#
#   Short_Question_Text
# 1    Health Insurance
# 3           Arthritis
# 5      Binge Drinking
#
# [3 rows x 24 columns]

# %%
# pivot so that we have columns for all the health measures, instead of a row for each
health_pivot = pd.pivot_table(health, values='Data_Value', index=['StateDesc', 'CityName'], 
                          columns=['Short_Question_Text'], aggfunc=np.sum).reset_index()
health_pivot.shape
# Out:
# (500, 30)

# %%
columns_locations = ['UniqueID','StateAbbr','StateDesc','CityName','GeographicLevel', 'TractFIPS','CityFIPS','GeoLocation']
columns_data_definition = ['Category', 'CategoryID', 'Measure','MeasureId','Data_Value_Type','Short_Question_Text']
columns_data = ['Data_Value','DataValueTypeID','Data_Value_Footnote_Symbol', 'Data_Value_Footnote','CategoryID',
                'GeoLocation','Low_Confidence_Limit', 'High_Confidence_Limit','PopulationCount','StateAbbr',
               'UniqueID','MeasureId','Year']

# %%
df_data_definition = df[columns_data_definition].copy()
df_data_definition = df_data_definition.drop_duplicates()
df_data_definition.to_csv('data_definition.csv')

df_data_definition.head(5)
# Out:
#               Category CategoryID  \
# 0           Prevention    PREVENT
# 1           Prevention    PREVENT
# 2      Health Outcomes    HLTHOUT
# 3      Health Outcomes    HLTHOUT
# 4  Unhealthy Behaviors     UNHBEH
#
#                                              Measure  MeasureId  \
# 0  Current lack of health insurance among adults ...    ACCESS2
# 1  Current lack of health insurance among adults ...    ACCESS2
# 2             Arthritis among adults aged >=18 Years  ARTHRITIS
# 3             Arthritis among adults aged >=18 Years  ARTHRITIS
# 4        Binge drinking among adults aged >=18 Years      BINGE
#
#            Data_Value_Type Short_Question_Text
# 0  Age-adjusted prevalence    Health Insurance
# 1         Crude prevalence    Health Insurance
# 2  Age-adjusted prevalence           Arthritis
# 3         Crude prevalence           Arthritis
# 4  Age-adjusted prevalence      Binge Drinking

# %%
df_data = df[columns_data].copy()

df_data_piv = df_data.pivot_table(values='Data_Value',
                          index=['UniqueID','DataValueTypeID','PopulationCount'],
                          columns='MeasureId',aggfunc=np.sum)
df_data_piv.reset_index(inplace=True)

# Save data where population count is > 50 (CDC website withholds data for population counts < 50)
df_data_piv[df_data_piv['PopulationCount']>50].to_csv('data.csv')

df_data_piv.head(5)
# Out:
# MeasureId             UniqueID DataValueTypeID  PopulationCount  ACCESS2  \
# 0                      0107000       AgeAdjPrv           212237     19.5
# 1                      0107000          CrdPrv           212237     19.2
# 2          0107000-01073000100          CrdPrv             3042     23.3
# 3          0107000-01073000300          CrdPrv             2735     28.5
# 4          0107000-01073000400          CrdPrv             3338     23.9
#
# MeasureId  ARTHRITIS  BINGE  BPHIGH  BPMED  CANCER  CASTHMA  ...  KIDNEY  \
# 0               29.3   13.0    44.1   70.1     5.7     10.5  ...     3.9
# 1               29.3   13.2    43.8   81.3     5.6     10.5  ...     3.8
# 2               31.3   11.5    46.2   80.0     5.2     11.8  ...     4.2
# 3               30.2   12.0    45.6   80.3     4.6     11.0  ...     4.3
# 4               31.7   11.6    50.1   82.0     5.2     11.8  ...     4.2
#
# MeasureId   LPA  MAMMOUSE  MHLTH  OBESITY  PAPTEST  PHLTH  SLEEP  STROKE  \
# 0          35.8      77.7   15.1     42.6     78.4   16.3   41.8     5.0
# 1          35.6      83.6   15.2     41.7     85.0   16.3   41.5     5.0
# 2          42.3      82.8   18.6     47.3     85.0   20.0   45.5     5.6
# 3          44.6      83.2   18.4     47.5     83.8   20.6   44.5     5.9
# 4          42.4      83.5   17.5     47.2     84.6   19.3   45.7     5.7
#
# MeasureId  TEETHLOST
# 0               22.9
# 1               22.8
# 2               28.9
# 3               32.9
# 4               28.6
#
# [5 rows x 31 columns]

# %%
df_locations = df[columns_locations].copy()

# df_locations = df_locations.drop_duplicates().sort_values('UniqueID')
# df_locations.to_csv('locations.csv')


lat = []
long =[]
for row in df_locations['GeoLocation']:
    # Try to,
    try:
        # Split the row by comma and append
        # everything before the comma to lat
        latitude = row.split(',')[0]
        latitude = latitude[1:]
        lat.append(latitude)
        # Split the row by comma and append
        # everything after the comma to lon
        longitude = row.split(',')[1]
        longitude = longitude[:-1]
        long.append(longitude)
        
    # But if you get an error
    except:
        # append a missing value to lat
        lat.append(np.NaN)
        # append a missing value to lon
        long.append(np.NaN)

# Create two new columns from lat and lon
df_locations['Latitude'] = lat
df_locations['Longitude'] = long

# df_locations.tail(5)
del df_locations['GeoLocation']
df_locations = df_locations.drop_duplicates().sort_values('UniqueID')
df_locations.to_csv('locations.csv')

df_locations.head(5)
# Out:
#                UniqueID StateAbbr StateDesc    CityName GeographicLevel  \
# 56              0107000        AL   Alabama  Birmingham            City
# 58  0107000-01073000100        AL   Alabama  Birmingham    Census Tract
# 59  0107000-01073000300        AL   Alabama  Birmingham    Census Tract
# 60  0107000-01073000400        AL   Alabama  Birmingham    Census Tract
# 61  0107000-01073000500        AL   Alabama  Birmingham    Census Tract
#
#        TractFIPS  CityFIPS       Latitude        Longitude
# 56           NaN  107000.0  33.5275663773   -86.7988174678
# 58  1.073000e+09  107000.0  33.5794328326   -86.7228323926
# 59  1.073000e+09  107000.0  33.5428208686    -86.752433978
# 60  1.073000e+09  107000.0  33.5632449633   -86.7640474064
# 61  1.073000e+09  107000.0  33.5442404594   -86.7749130719

# %%
data = pd.read_csv('data.csv',index_col=0)
locations = pd.read_csv('locations.csv',index_col=0)

# %%
#Fill CITY OF UNITED STATES FOR AGG FUNCTIONS inplace of NAN, 
locations.CityName = locations.CityName.fillna('United States') 

#combining data and locations dataframes

combined_df = data.set_index('UniqueID').join(locations.set_index('UniqueID'))
combined_df['GeographicLevel'].value_counts()
# Out:
# Census Tract    27204
# City             1000
# US                  2
# Name: GeographicLevel, dtype: int64

# %% [markdown]
# # Missing Data ?

# %%
data.describe().sort_values('count',axis=1)
# Out:
#               COREW         COREM     TEETHLOST      MAMMOUSE  COLON_SCREEN  \
# count  28097.000000  28103.000000  28146.000000  28169.000000  28187.000000
# mean      29.894825     31.744116     16.052718     79.100824     61.860744
# std        7.129601      8.007127      8.678731      3.329118      8.692745
# min        9.600000     11.900000      2.800000     59.200000     29.400000
# 25%       24.400000     25.400000      9.200000     77.100000     55.900000
# 50%       30.000000     32.000000     14.100000     79.300000     62.900000
# 75%       35.100000     37.500000     21.100000     81.400000     68.500000
# max       55.100000     58.900000     57.000000     88.200000     85.700000
#
#             PAPTEST       ACCESS2         BINGE         SLEEP         PHLTH  \
# count  28199.000000  28205.000000  28206.000000  28206.000000  28206.000000
# mean      76.262070     16.204733     17.636953     36.673357     12.746632
# std       22.870936      8.950267      4.106624      5.910246      4.085621
# min        0.000000      2.500000      2.700000     16.100000      3.200000
# 25%       80.400000      9.500000     15.000000     32.400000      9.700000
# 50%       83.000000     14.100000     17.300000     36.100000     12.100000
# 75%       85.100000     20.900000     19.900000     40.500000     15.400000
# max       90.300000     58.500000     44.800000     58.700000     35.800000
#
#        ...          COPD    CHOLSCREEN       CHECKUP           CHD  \
# count  ...  28206.000000  28206.000000  28206.000000  28206.000000
# mean   ...      6.314188     72.656176     69.384237      5.810335
# std    ...      2.424938      8.305593      6.387542      2.061603
# min    ...      1.100000     21.700000     44.900000      0.300000
# 25%    ...      4.600000     67.800000     64.700000      4.500000
# 50%    ...      5.900000     73.400000     69.100000      5.600000
# 75%    ...      7.600000     78.500000     74.100000      6.900000
# max    ...     24.200000     95.500000     91.300000     34.400000
#
#             CASTHMA        CANCER         BPMED        BPHIGH        DENTAL  \
# count  28206.000000  28206.000000  28206.000000  28206.000000  28206.000000
# mean       9.684677      5.508250     71.966071     30.490233     61.303304
# std        1.842656      1.749507      7.852176      8.209492     12.787651
# min        5.100000      0.600000     11.500000      4.900000     18.900000
# 25%        8.300000      4.400000     68.000000     25.400000     51.800000
# 50%        9.300000      5.300000     73.000000     29.300000     62.900000
# 75%       10.700000      6.400000     77.200000     34.400000     71.600000
# max       19.100000     21.900000     93.200000     71.000000     88.900000
#
#        PopulationCount
# count     2.820600e+04
# mean      3.284909e+04
# std       2.601385e+06
# min       5.100000e+01
# 25%       2.499000e+03
# 50%       3.694000e+03
# 75%       5.079000e+03
# max       3.087455e+08
#
# [8 rows x 29 columns]

# %% [markdown]
# Here, 7 columns are likely to have missing data out of 29 total columns.
# 109 rows is likely to have most missing information, equivalent to 3% of total information.

# %%
missingData = data[data.isnull().values].join(locations[['UniqueID','CityName','GeographicLevel']].
                                              set_index('UniqueID'),on='UniqueID',how='left')

#value counts of missing data by geographic level
print(missingData['GeographicLevel'].value_counts(),end='\n\n')

#value counts of all data by geographic level
print(data.join(locations[['UniqueID','CityName','GeographicLevel']].
                set_index('UniqueID'),on='UniqueID',how='left')['GeographicLevel'].value_counts())
# Out:
# Census Tract    336
# Name: GeographicLevel, dtype: int64
#
# Census Tract    27204
# City             1000
# US                  2
# Name: GeographicLevel, dtype: int64

# %% [markdown]
# Census Tract    336
# i.e. 1% missing data out of 27198.
# No rolled up cities are missing data as well as the rolled up united states.
#
# Now I'll build a dataframe that includes only missing data grouped by city, showing the mean population of the census tracts with missing data, the count of census tracts in each city missing data, the count of total census tracts from those cities, and the % of census tracts that are missing from each city

# %%
missingDataPopMean = missingData.groupby('CityName')['PopulationCount'].mean()
missingDataCensusCount = missingData.groupby('CityName')['UniqueID'].count()
missingDataJoined = pd.concat([missingDataPopMean,missingDataCensusCount],axis=1,keys=['AvgPop','MissingCensusCount'])
fullDataCensusCount = data.join(locations[['UniqueID','CityName','GeographicLevel']].set_index('UniqueID'),on='UniqueID',how='left').groupby('CityName')['UniqueID'].count()
missingDataCities = missingDataJoined.join(fullDataCensusCount,how='left')
missingDataCities.columns = ['Avg Population','Num Census Tracts Missing','CensusTract Count']
missingDataCities['perMissing'] = missingDataCities.iloc[:,1]/missingDataCities.iloc[:,2]
missingDataCities.sort_values('perMissing',ascending=False,inplace=True)
print('TOP AND BOTTOM 5 Cities Missing Percentage Of Censuses')
pd.concat([missingDataCities.head(10)])
# Out:
# TOP AND BOTTOM 5 Cities Missing Percentage Of Censuses
#                  Avg Population  Num Census Tracts Missing  CensusTract Count  \
# CityName
# Santa Maria          147.000000                          6                 20
# Fayetteville        1709.733333                         15                 69
# Rock Hill           1762.000000                          5                 24
# Gulfport              85.000000                          5                 24
# Missouri City         56.750000                          4                 20
# Abilene             1700.428571                          7                 39
# Boca Raton          2224.000000                          5                 29
# Miami Beach           59.000000                          5                 31
# Portsmouth            78.000000                          5                 33
# College Station     6964.250000                          4                 28
#
#                  perMissing
# CityName
# Santa Maria        0.300000
# Fayetteville       0.217391
# Rock Hill          0.208333
# Gulfport           0.208333
# Missouri City      0.200000
# Abilene            0.179487
# Boca Raton         0.172414
# Miami Beach        0.161290
# Portsmouth         0.151515
# College Station    0.142857

# %% [markdown]
# So, we clean data by filling census tract NANs with data from mean values of the same city

# %%
cleanedData = data.join(locations[['UniqueID','CityName','StateAbbr','GeographicLevel']].
                        set_index('UniqueID'),on='UniqueID',how='left').copy()
colsToClean = cleanedData.drop(['UniqueID','CityName','StateAbbr','DataValueTypeID','PopulationCount','GeographicLevel'],axis=1).columns
for col in colsToClean:
    cleanedData[col] = cleanedData.groupby('CityName')[col].transform(lambda x: x.fillna(np.mean(x)))

# %%
# Check cleaned Data For Missing Values. 
cleanedData.describe().sort_values('count',axis=1)
# Out:
#        PopulationCount         SLEEP         PHLTH       PAPTEST  \
# count     2.820600e+04  28206.000000  28206.000000  28206.000000
# mean      3.284909e+04     36.673357     12.746632     76.260786
# std       2.601385e+06      5.910246      4.085621     22.872821
# min       5.100000e+01     16.100000      3.200000      0.000000
# 25%       2.499000e+03     32.400000      9.700000     80.400000
# 50%       3.694000e+03     36.100000     12.100000     83.000000
# 75%       5.079000e+03     40.500000     15.400000     85.100000
# max       3.087455e+08     58.700000     35.800000     90.300000
#
#             OBESITY         MHLTH      MAMMOUSE           LPA        KIDNEY  \
# count  28206.000000  28206.000000  28206.000000  28206.000000  28206.000000
# mean      30.068010     13.097309     79.101451     25.417698      2.969588
# std        8.159912      3.372001      3.328724      9.222433      0.942972
# min        9.100000      4.100000     59.200000      7.100000      0.500000
# 25%       24.000000     10.500000     77.100000     18.100000      2.300000
# 50%       29.100000     12.700000     79.300000     24.100000      2.800000
# 75%       35.100000     15.300000     81.400000     31.700000      3.400000
# max       57.500000     29.400000     88.200000     62.100000     12.000000
#
#            HIGHCHOL  ...           CHD       CASTHMA        CANCER  \
# count  28206.000000  ...  28206.000000  28206.000000  28206.000000
# mean      34.529792  ...      5.810335      9.684677      5.508250
# std        5.144286  ...      2.061603      1.842656      1.749507
# min        7.400000  ...      0.300000      5.100000      0.600000
# 25%       31.800000  ...      4.500000      8.300000      4.400000
# 50%       34.800000  ...      5.600000      9.300000      5.300000
# 75%       37.800000  ...      6.900000     10.700000      6.400000
# max       57.700000  ...     34.400000     19.100000     21.900000
#
#               BPMED        BPHIGH         BINGE     ARTHRITIS       ACCESS2  \
# count  28206.000000  28206.000000  28206.000000  28206.000000  28206.000000
# mean      71.966071     30.490233     17.636953     22.347135     16.204594
# std        7.852176      8.209492      4.106624      6.327541      8.950138
# min       11.500000      4.900000      2.700000      2.000000      2.500000
# 25%       68.000000     25.400000     15.000000     18.000000      9.500000
# 50%       73.000000     29.300000     17.300000     21.900000     14.100000
# 75%       77.200000     34.400000     19.900000     26.200000     20.900000
# max       93.200000     71.000000     44.800000     60.700000     58.500000
#
#               COREM     TEETHLOST
# count  28206.000000  28206.000000
# mean      31.744566     16.052887
# std        7.998154      8.671769
# min       11.900000      2.800000
# 25%       25.500000      9.200000
# 50%       32.000000     14.100000
# 75%       37.500000     21.100000
# max       58.900000     57.000000
#
# [8 rows x 29 columns]

# %%
fig, ax = plt.subplots(1,1,figsize=(20,10))
sns.boxplot(data=cleanedData.drop(['PopulationCount'],axis=1),ax=ax,orient='horizontal')
plt.show()

# %% [markdown]
# From the boxplot, we see that there are many census tracts that fall outside of of the inter quartile ranges (outliers). however, we don't believe they are erroneous data. This could be cause by low sample size of certain census tracts or there are truly many census tracts that fall outside of the inter quartile ranges.
#
#
# So, we'll look at the outliers at a city level to see if there's much of a difference.

# %%
data.columns
# Out:
# Index(['UniqueID', 'DataValueTypeID', 'PopulationCount', 'ACCESS2',
#        'ARTHRITIS', 'BINGE', 'BPHIGH', 'BPMED', 'CANCER', 'CASTHMA', 'CHD',
#        'CHECKUP', 'CHOLSCREEN', 'COLON_SCREEN', 'COPD', 'COREM', 'COREW',
#        'CSMOKING', 'DENTAL', 'DIABETES', 'HIGHCHOL', 'KIDNEY', 'LPA',
#        'MAMMOUSE', 'MHLTH', 'OBESITY', 'PAPTEST', 'PHLTH', 'SLEEP', 'STROKE',
#        'TEETHLOST'],
#       dtype='object')

# %%
locations.columns
# Out:
# Index(['UniqueID', 'StateAbbr', 'StateDesc', 'CityName', 'GeographicLevel',
#        'TractFIPS', 'CityFIPS', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
tst = cleanedData[cleanedData['GeographicLevel']=='Census Tract'].set_index('UniqueID').drop(['CityName','StateAbbr','GeographicLevel','DataValueTypeID','PopulationCount'],axis=1)
tst1 = tst.multiply(cleanedData[cleanedData['GeographicLevel']=='Census Tract'].set_index('UniqueID')['PopulationCount'],axis=0)
tst2 = tst1.join(cleanedData[cleanedData['GeographicLevel']=='Census Tract'].set_index('UniqueID')[['StateAbbr','CityName']]).groupby(['StateAbbr','CityName']).agg(np.sum)
tst3 = tst2.divide(cleanedData[cleanedData['GeographicLevel']=='Census Tract'].groupby(['StateAbbr','CityName'])['PopulationCount'].sum(),axis=0)

fig, ax = plt.subplots(1,1,figsize=(20,12))
_  = sns.boxplot(data=tst3,orient='horizontal')
plt.show()

# %% [markdown]
# It looks like most of the data points are similar to a normal distribution.
# We think now this data is clean and ready for EDA. And, also, to save it for future Use!

# %%
cleanedData.drop(['GeographicLevel','StateAbbr','CityName'],axis=1).to_csv('data.csv')
locations.to_csv('locations.csv')

# %% [markdown]
# # Reframing the data

# %%
data = pd.read_csv('data.csv')
dataDef = pd.read_csv('data_definition.csv')
locations = pd.read_csv('locations.csv')

# %% [markdown]
# We separate health outcomes from unhealthy behaviors and preventative measures by joining operations and building various dataframes.

# %%
data.head(3)
# Out:
#    Unnamed: 0             UniqueID DataValueTypeID  PopulationCount  ACCESS2  \
# 0           0              0107000       AgeAdjPrv           212237     19.5
# 1           1              0107000          CrdPrv           212237     19.2
# 2           2  0107000-01073000100          CrdPrv             3042     23.3
#
#    ARTHRITIS  BINGE  BPHIGH  BPMED  CANCER  ...  KIDNEY   LPA  MAMMOUSE  \
# 0       29.3   13.0    44.1   70.1     5.7  ...     3.9  35.8      77.7
# 1       29.3   13.2    43.8   81.3     5.6  ...     3.8  35.6      83.6
# 2       31.3   11.5    46.2   80.0     5.2  ...     4.2  42.3      82.8
#
#    MHLTH  OBESITY  PAPTEST  PHLTH  SLEEP  STROKE  TEETHLOST
# 0   15.1     42.6     78.4   16.3   41.8     5.0       22.9
# 1   15.2     41.7     85.0   16.3   41.5     5.0       22.8
# 2   18.6     47.3     85.0   20.0   45.5     5.6       28.9
#
# [3 rows x 32 columns]

# %%
dataDef.head(3)
# Out:
#    Unnamed: 0         Category CategoryID  \
# 0           0       Prevention    PREVENT
# 1           1       Prevention    PREVENT
# 2           2  Health Outcomes    HLTHOUT
#
#                                              Measure  MeasureId  \
# 0  Current lack of health insurance among adults ...    ACCESS2
# 1  Current lack of health insurance among adults ...    ACCESS2
# 2             Arthritis among adults aged >=18 Years  ARTHRITIS
#
#            Data_Value_Type Short_Question_Text
# 0  Age-adjusted prevalence    Health Insurance
# 1         Crude prevalence    Health Insurance
# 2  Age-adjusted prevalence           Arthritis

# %%
locations.head(3)
# Out:
#    Unnamed: 0             UniqueID StateAbbr StateDesc    CityName  \
# 0          56              0107000        AL   Alabama  Birmingham
# 1          58  0107000-01073000100        AL   Alabama  Birmingham
# 2          59  0107000-01073000300        AL   Alabama  Birmingham
#
#   GeographicLevel     TractFIPS  CityFIPS   Latitude  Longitude
# 0            City           NaN  107000.0  33.527566 -86.798817
# 1    Census Tract  1.073000e+09  107000.0  33.579433 -86.722832
# 2    Census Tract  1.073000e+09  107000.0  33.542821 -86.752434

# %%
data2 = data.set_index('UniqueID').join(locations.set_index('UniqueID')['GeographicLevel']).copy()
data2 = data2[data2['GeographicLevel'] == 'Census Tract']
data2 = data2.drop(['Unnamed: 0','DataValueTypeID','GeographicLevel'],axis=1).reset_index()

# %%
dataMelt = data2.melt(id_vars=['UniqueID','PopulationCount'],var_name='MeasureID')
dataMelt.head(3)
# Out:
#               UniqueID  PopulationCount MeasureID  value
# 0  0107000-01073000100             3042   ACCESS2   23.3
# 1  0107000-01073000300             2735   ACCESS2   28.5
# 2  0107000-01073000400             3338   ACCESS2   23.9

# %%
dataDef2 = dataDef[['MeasureId','Category']].drop_duplicates()
dataDef2.head(3)
# Out:
#    MeasureId             Category
# 0    ACCESS2           Prevention
# 2  ARTHRITIS      Health Outcomes
# 4      BINGE  Unhealthy Behaviors

# %%
joined = dataMelt.set_index('MeasureID').join(dataDef2.set_index('MeasureId'), how='left').reset_index().set_index(['UniqueID','PopulationCount'])

# %%
joined.head(5)
# Out:
#                                        index  value    Category
# UniqueID            PopulationCount
# 0107000-01073000100 3042             ACCESS2   23.3  Prevention
# 0107000-01073000300 2735             ACCESS2   28.5  Prevention
# 0107000-01073000400 3338             ACCESS2   23.9  Prevention
# 0107000-01073000500 2864             ACCESS2   25.8  Prevention
# 0107000-01073000700 2577             ACCESS2   29.4  Prevention

# %% [markdown]
# Separating Prevention,Health Outcomes and Unhealthy Behaviors into three different dataframes.

# %%
preventative = joined[joined['Category'] == 'Prevention'].copy()
outcomes = joined[joined['Category'] == 'Health Outcomes'].copy()
unhealthy = joined[(joined['Category'] == 'Unhealthy Behaviors') | (joined['Category'] == 'Prevention')].copy()

# %%
preventative.head(3)
# Out:
#                                        index  value    Category
# UniqueID            PopulationCount
# 0107000-01073000100 3042             ACCESS2   23.3  Prevention
# 0107000-01073000300 2735             ACCESS2   28.5  Prevention
# 0107000-01073000400 3338             ACCESS2   23.9  Prevention

# %%
outcomes.head(3)
# Out:
#                                          index  value         Category
# UniqueID            PopulationCount
# 0107000-01073000100 3042             ARTHRITIS   31.3  Health Outcomes
# 0107000-01073000300 2735             ARTHRITIS   30.2  Health Outcomes
# 0107000-01073000400 3338             ARTHRITIS   31.7  Health Outcomes

# %%
unhealthy.head(3)
# Out:
#                                        index  value    Category
# UniqueID            PopulationCount
# 0107000-01073000100 3042             ACCESS2   23.3  Prevention
# 0107000-01073000300 2735             ACCESS2   28.5  Prevention
# 0107000-01073000400 3338             ACCESS2   23.9  Prevention

# %% [markdown]
# # Exploratory data analysis And Visualizations

# %%
# Pivot table on cities & multi index categories & short question text (short for measure). average on Data Value. 
category = df['Category'] == 'Health Outcomes'
dfPiv = df.pivot_table(index='CityName',columns=['Category','Short_Question_Text'],values='Data_Value',aggfunc=np.mean)

#Create zscore for all columns to standardize data
dfPivZscore = dfPiv.apply(zscore)

# %%
#Plot Heatmap of correlations between preventative activites and health outcomes

fig, ax = plt.subplots(figsize=(10,7))
ax = sns.heatmap(dfPivZscore.corr().loc['Health Outcomes','Prevention'],annot=True)
#plt.setp(ax.ax_heatmap.get_yticklabels(), rotation=0);
plt.title('Correlations between Negative Health Outcomes vs Preventative Activities')
plt.ylabel('Negative Health Outcomes')
plt.xlabel('Preventative Activities')
# Out:
# Text(0.5, 42.0, 'Preventative Activities')

# %%
#Plot Heatmap of correlations between unhealthy behaviors  and health outcomes

fig, ax = plt.subplots(figsize=(10,7))
ax = sns.heatmap(dfPivZscore.corr().loc['Health Outcomes','Unhealthy Behaviors'],annot=True)
#plt.setp(ax.ax_heatmap.get_yticklabels(), rotation=0);
plt.title('Correlations between Negative Health Outcomes vs Unhealthy Behaviors')
plt.ylabel('Negative Health Outcomes')
plt.xlabel('Unhealthy Behaviors')
# Out:
# Text(0.5, 42.0, 'Unhealthy Behaviors')

# %%
dfcorr = health_pivot.corr().round(3)
df_1 = pd.DataFrame()
for i, col1 in enumerate(dfcorr.columns):
    for j, col2 in enumerate(dfcorr.columns):
        df_1 = df_1.append({'col1':col1, 'col2': col2, 'cor': dfcorr.iloc[i,j]}, ignore_index=True)
df_1 = df_1[(df_1.cor!=1) & (df_1.col2!='health_score')& (df_1.col1!='health_score')]
df_1 = df_1.drop_duplicates(subset='cor', keep='first')
df_1['abs_cor'] = np.abs(df_1.cor)
df_1 = df_1.sort_values('abs_cor', ascending=False)
df_1 = df_1.drop("abs_cor",axis=1).reset_index()
df_1.head(15)
# Out:
#     index                    col1                    col2    cor
# 0     193  Chronic Kidney Disease                  Stroke  0.939
# 1     182  Chronic Kidney Disease                Diabetes  0.925
# 2      94                    COPD  Coronary Heart Disease  0.919
# 3     190  Chronic Kidney Disease         Physical Health  0.916
# 4     109                    COPD                  Stroke  0.904
# 5     473     High Blood Pressure                  Stroke  0.898
# 6     305  Coronary Heart Disease                  Stroke  0.896
# 7     178  Chronic Kidney Disease  Coronary Heart Disease  0.877
# 8     559           Mental Health              Teeth Loss  0.875
# 9     106                    COPD         Physical Health  0.874
# 10    414                Diabetes         Physical Health  0.868
# 11    363         Current Smoking              Teeth Loss  0.861
# 12     96                    COPD         Current Smoking  0.860
# 13    643         Physical Health              Teeth Loss  0.859
# 14    415                Diabetes     Physical Inactivity  0.858

# %% [markdown]
# Some high level takeaways:
#
# 1. Lack of health insurance is positively correlated with negative health outcomes (i.e. people without health insurance experience worse health outcomes). => This is interesting although not surprising.
#
# 2. Binge drinking seems to be inversely correlated with all health outcomes. This comes as a surprise to me. My first thought on this is that binge drinking is more common among young people who generally don’t have as many health issues as older people. However we would need to analyze data on binge drinking more extensively to derive solid conclusions.
#
# 3. Lack of sleep, Low physical activity, and having obesity all seem to highly correlate with health outcomes, especially poor mental health, physical health, and teeth loss.
#
# We think there is some collinearity in LPA, Obesity, and C

# %%
#build a histogram for health insurance across the dataset by city.
city_data = df[df["GeographicLevel"] == "City"] 
stats_city_health_insurance = city_data[(city_data['Short_Question_Text']=='Health Insurance') 
                                        & (city_data['DataValueTypeID'] == 'AgeAdjPrv')]
# f, ax = plt.subplots(figsize=(11, 9))
# sns.boxplot(x='Short_Question_Text',y='Data_Value',hue='Category', data= city_data, orient='v')
# # plt.show()

stats_city_health_insurance['Data_Value'].describe()
# Out:
# count    500.000000
# mean      15.528800
# std        6.210797
# min        4.400000
# 25%       11.100000
# 50%       14.200000
# 75%       18.900000
# max       43.700000
# Name: Data_Value, dtype: float64

# %% [markdown]
# There is a wide range of health insurance coverage across the cities in the dataset with a difference between the best and worst of about 40 percent.

# %%
ax = stats_city_health_insurance['Data_Value'].hist()

# %% [markdown]
# The histogram shows the data is skewed to the right.
# Now, We try to find the cities which have the highest percentage of their population lacking health insurance.

# %%
stats_city_least_healthinsurance = stats_city_health_insurance.sort_values('Data_Value', ascending=False)
stats_city_least_healthinsurance[['CityName','StateAbbr','Data_Value']].head(20)
# Out:
#               CityName StateAbbr  Data_Value
# 243987         Hialeah        FL        43.7
# 742305           Pharr        TX        43.3
# 682284     Brownsville        TX        41.4
# 730007          Laredo        TX        41.0
# 738987         Mission        TX        36.5
# 254464           Miami        FL        36.3
# 698094        Edinburg        TX        35.5
# 735511         McAllen        TX        34.4
# 740771        Pasadena        TX        32.8
# 698514         El Paso        TX        32.7
# 474897         Passaic        NJ        31.3
# 322614          Cicero        IL        30.7
# 258292   Miami Gardens        FL        29.6
# 746497     San Antonio        TX        29.0
# 477081      Union City        NJ        28.8
# 710825         Houston        TX        28.2
# 688226          Dallas        TX        28.1
# 468627          Camden        NJ        28.1
# 686072  Corpus Christi        TX        28.0
# 475345        Paterson        NJ        28.0

# %% [markdown]
# EDA: In Hialeah,FL nearly half of their population lacks health insurance and Texas leads the way with 8 of top 10 cities.
#
# =>Texas is a large state and they may simply have more cities in the dataset than other states.
#
# Now, we will calculate the ratio of cities from each state in the top 100 with regards to lack of health insurance in comparison to the total number of cities in the dataset.

# %%
#Select the top 100 cities by lack of health insurance
top_100_lacking_insurance = stats_city_least_healthinsurance[:100]
grouped_state_top100 = top_100_lacking_insurance.groupby('StateDesc').count()
grouped_state_top100.head(10)
# Out:
#                Year  StateAbbr  CityName  GeographicLevel  DataSource  \
# StateDesc
# Arizona           1          1         1                1           1
# California       14         14        14               14          14
# Colorado          1          1         1                1           1
# Florida          25         25        25               25          25
# Georgia           5          5         5                5           5
# Idaho             1          1         1                1           1
# Illinois          2          2         2                2           2
# Indiana           1          1         1                1           1
# Kansas            1          1         1                1           1
# Massachusetts     1          1         1                1           1
#
#                Category  UniqueID  Measure  Data_Value_Unit  DataValueTypeID  \
# StateDesc
# Arizona               1         1        1                1                1
# California           14        14       14               14               14
# Colorado              1         1        1                1                1
# Florida              25        25       25               25               25
# Georgia               5         5        5                5                5
# Idaho                 1         1        1                1                1
# Illinois              2         2        2                2                2
# Indiana               1         1        1                1                1
# Kansas                1         1        1                1                1
# Massachusetts         1         1        1                1                1
#
#                ...  High_Confidence_Limit  Data_Value_Footnote_Symbol  \
# StateDesc      ...
# Arizona        ...                      1                           0
# California     ...                     14                           0
# Colorado       ...                      1                           0
# Florida        ...                     25                           0
# Georgia        ...                      5                           0
# Idaho          ...                      1                           0
# Illinois       ...                      2                           0
# Indiana        ...                      1                           0
# Kansas         ...                      1                           0
# Massachusetts  ...                      1                           0
#
#                Data_Value_Footnote  PopulationCount  GeoLocation  CategoryID  \
# StateDesc
# Arizona                          0                1            1           1
# California                       0               14           14          14
# Colorado                         0                1            1           1
# Florida                          0               25           25          25
# Georgia                          0                5            5           5
# Idaho                            0                1            1           1
# Illinois                         0                2            2           2
# Indiana                          0                1            1           1
# Kansas                           0                1            1           1
# Massachusetts                    0                1            1           1
#
#                MeasureId  CityFIPS  TractFIPS  Short_Question_Text
# StateDesc
# Arizona                1         1          0                    1
# California            14        14          0                   14
# Colorado               1         1          0                    1
# Florida               25        25          0                   25
# Georgia                5         5          0                    5
# Idaho                  1         1          0                    1
# Illinois               2         2          0                    2
# Indiana                1         1          0                    1
# Kansas                 1         1          0                    1
# Massachusetts          1         1          0                    1
#
# [10 rows x 23 columns]

# %%
#Count the total cities in the dataset for each state
grouped_state = stats_city_health_insurance.groupby('StateDesc').count()
grouped_state.head(5)
# Out:
#             Year  StateAbbr  CityName  GeographicLevel  DataSource  Category  \
# StateDesc
# Alabama        6          6         6                6           6         6
# Alaska         1          1         1                1           1         1
# Arizona       12         12        12               12          12        12
# Arkansas       5          5         5                5           5         5
# California   121        121       121              121         121       121
#
#             UniqueID  Measure  Data_Value_Unit  DataValueTypeID  ...  \
# StateDesc                                                        ...
# Alabama            6        6                6                6  ...
# Alaska             1        1                1                1  ...
# Arizona           12       12               12               12  ...
# Arkansas           5        5                5                5  ...
# California       121      121              121              121  ...
#
#             High_Confidence_Limit  Data_Value_Footnote_Symbol  \
# StateDesc
# Alabama                         6                           0
# Alaska                          1                           0
# Arizona                        12                           0
# Arkansas                        5                           0
# California                    121                           0
#
#             Data_Value_Footnote  PopulationCount  GeoLocation  CategoryID  \
# StateDesc
# Alabama                       0                6            6           6
# Alaska                        0                1            1           1
# Arizona                       0               12           12          12
# Arkansas                      0                5            5           5
# California                    0              121          121         121
#
#             MeasureId  CityFIPS  TractFIPS  Short_Question_Text
# StateDesc
# Alabama             6         6          0                    6
# Alaska              1         1          0                    1
# Arizona            12        12          0                   12
# Arkansas            5         5          0                    5
# California        121       121          0                  121
#
# [5 rows x 23 columns]

# %% [markdown]
# # ML Analysis

# %%
from sklearn.model_selection import cross_val_score,GridSearchCV,train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.decomposition import NMF,PCA
from sklearn.metrics import accuracy_score, r2_score
import statsmodels.api as sm
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns

# %%
#load individual datasets
data = pd.read_csv('data.csv',index_col=0).set_index('UniqueID')
locations = pd.read_csv('locations.csv')

# %%
data.columns
# Out:
# Index(['DataValueTypeID', 'PopulationCount', 'ACCESS2', 'ARTHRITIS', 'BINGE',
#        'BPHIGH', 'BPMED', 'CANCER', 'CASTHMA', 'CHD', 'CHECKUP', 'CHOLSCREEN',
#        'COLON_SCREEN', 'COPD', 'COREM', 'COREW', 'CSMOKING', 'DENTAL',
#        'DIABETES', 'HIGHCHOL', 'KIDNEY', 'LPA', 'MAMMOUSE', 'MHLTH', 'OBESITY',
#        'PAPTEST', 'PHLTH', 'SLEEP', 'STROKE', 'TEETHLOST'],
#       dtype='object')

# %%
locations.columns
# Out:
# Index(['Unnamed: 0', 'UniqueID', 'StateAbbr', 'StateDesc', 'CityName',
#        'GeographicLevel', 'TractFIPS', 'CityFIPS', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
# join locations data
main = data.join(locations.set_index('UniqueID')[['GeographicLevel','StateAbbr','CityName']]).copy()

# Only keep census level data
main = main[main['GeographicLevel'] == 'Census Tract']

# %%
main = main.drop(['GeographicLevel','StateAbbr','CityName', 'DataValueTypeID'],axis=1).reset_index().set_index('UniqueID')
main.head()
# Out:
#                      PopulationCount  ACCESS2  ARTHRITIS  BINGE  BPHIGH  \
# UniqueID
# 0107000-01073000100             3042     23.3       31.3   11.5    46.2
# 0107000-01073000300             2735     28.5       30.2   12.0    45.6
# 0107000-01073000400             3338     23.9       31.7   11.6    50.1
# 0107000-01073000500             2864     25.8       35.6   10.0    54.3
# 0107000-01073000700             2577     29.4       37.2    8.4    55.4
#
#                      BPMED  CANCER  CASTHMA   CHD  CHECKUP  ...  KIDNEY   LPA  \
# UniqueID                                                    ...
# 0107000-01073000100   80.0     5.2     11.8   8.1     76.6  ...     4.2  42.3
# 0107000-01073000300   80.3     4.6     11.0   8.3     73.9  ...     4.3  44.6
# 0107000-01073000400   82.0     5.2     11.8   8.0     78.1  ...     4.2  42.4
# 0107000-01073000500   84.0     5.8     12.1  10.1     79.5  ...     5.2  46.5
# 0107000-01073000700   83.3     5.7     13.2  11.4     79.5  ...     6.2  52.4
#
#                      MAMMOUSE  MHLTH  OBESITY  PAPTEST  PHLTH  SLEEP  STROKE  \
# UniqueID
# 0107000-01073000100      82.8   18.6     47.3     85.0   20.0   45.5     5.6
# 0107000-01073000300      83.2   18.4     47.5     83.8   20.6   44.5     5.9
# 0107000-01073000400      83.5   17.5     47.2     84.6   19.3   45.7     5.7
# 0107000-01073000500      83.8   18.2     49.5     84.3   21.8   46.1     7.7
# 0107000-01073000700      83.4   21.1     53.4     84.5   25.1   48.3     9.5
#
#                      TEETHLOST
# UniqueID
# 0107000-01073000100       28.9
# 0107000-01073000300       32.9
# 0107000-01073000400       28.6
# 0107000-01073000500       34.0
# 0107000-01073000700       43.2
#
# [5 rows x 29 columns]

# %%
# Contextualy irrelevant features
#dropping data irrelevant
drop_data = np.array(['MAMMOUSE','PAPTEST','BPMED','TEETHLOST','DENTAL']) 


# Drop effects/irrelevant features
mainData = main.drop(np.concatenate([drop_data]),axis=1)

# %%
fig,ax = plt.subplots(figsize=(15,5))
sns.heatmap(mainData.drop('CANCER',axis=1).corr(),annot=True, cmap='RdYlGn')
plt.title('Correlation of Features')
plt.show()

# %%
#drop correlations not required as of now
mainData.drop(['LPA','COREW','PopulationCount','CHOLSCREEN', 'ACCESS2', 'CHD', 'PHLTH', 'COLON_SCREEN', 'MHLTH','COPD'],axis=1,inplace=True)

# %%
# y is the feature in question (CANCER)
# X is the other features in question

y = mainData['CANCER']
X = mainData.drop('CANCER',axis=1)

Xtrain, Xtest, ytrain, ytest = train_test_split(X,y,test_size=.25)

# %%
#check for any missing/abnormal data
summaryofmainData = sm.OLS(ytrain,Xtrain).fit()
abnormalData = summaryofmainData.resid[summaryofmainData.resid <= -.10]

# %%
#find the summary of abnormal data in the dataset
a = np.empty(len(Xtrain.index.values),dtype=np.bool)
for i,j in enumerate(Xtrain.index.values):
    a[i] = True if j in abnormalData.index.values else False
summaryofabnormalData = sm.OLS(ytrain[~a],Xtrain[~a]).fit()

# %%
#Obtain Coefficient confidence intervals
alp = .05
confidenceinterval = summaryofabnormalData.conf_int(alpha=alp)
confidenceinterval.columns =['low','high']
confidenceinterval.sort_values('low',ascending=False)
# Out:
#                 low      high
# KIDNEY     0.908751  0.970695
# ARTHRITIS  0.196862  0.201659
# STROKE     0.100622  0.146184
# HIGHCHOL   0.072615  0.077367
# CHECKUP    0.041318  0.043867
# BPHIGH     0.039835  0.045308
# COREM      0.011221  0.013490
# BINGE     -0.005988 -0.001905
# SLEEP     -0.043343 -0.039633
# OBESITY   -0.054409 -0.051308
# CSMOKING  -0.076965 -0.072682
# CASTHMA   -0.101832 -0.091772
# DIABETES  -0.344667 -0.332682

# %%
## R2 scoring for cross_val_score scoring
def scorer(t,X,y):
    t.fit(X,y)
    ypred = t.predict(X)
    return r2_score(y,ypred)

# %%
#Set Model for Regression and Print
snf = LinearRegression()

snf.fit(Xtrain[~a],ytrain[~a])

print('Model Accuracy :')
print('Linear Regression R2: {:.4f}'.format(snf.score(Xtrain[~a],ytrain[~a])))
print('Cross Fold Validation: ')
print('Linear Regression Cross Val Score: {}'.format(cross_val_score(snf,Xtrain[~a],ytrain[~a],cv= 20,scoring=scorer)))
pd.DataFrame(snf.coef_,index=Xtrain[~a].columns,columns=['Coefs']).sort_values('Coefs',ascending=False).sort_values('Coefs',ascending=False)
# Out:
# Model Accuracy :
# Linear Regression R2: 0.9815
# Cross Fold Validation:
# Linear Regression Cross Val Score: [0.98388758 0.97908431 0.98347111 0.98078969 0.98098598 0.98452426
#  0.98434933 0.98331103 0.98099294 0.98163679 0.98180881 0.98450266
#  0.98395152 0.98108366 0.98074712 0.98160745 0.9810244  0.97814215
#  0.98293826 0.98267336]
#               Coefs
# KIDNEY     0.804794
# ARTHRITIS  0.210617
# STROKE     0.150400
# HIGHCHOL   0.064198
# BPHIGH     0.045714
# CHECKUP    0.037239
# COREM      0.006823
# BINGE     -0.009183
# SLEEP     -0.046696
# OBESITY   -0.055068
# CSMOKING  -0.074376
# CASTHMA   -0.106979
# DIABETES  -0.323450

# %% [markdown]
# # Reflection

# %% [markdown]
# What is hardest part of the project that you’ve encountered so far:
# 1. Finding an appropriate hypothesis
# 2. Machine Learning algorithm implementation
#
# What are your initial insights?
# 1. Obesity is highly correlated to Physical Inactivity.
# 2. Cancer and Binge Drinking are highly correlated.
# 3. NYC has the highest number of hospitals amongst various cities of the US. More analysis needs to be done regarding the Timely and Effective Care measures provided by various Hospitals in different parts of the States
#
# Are there any concrete results you can show at this point? If not, why not?
# 1.
#
# Going forward, what are the current biggest problems you’re facing?
# 1. Joining datasets and applying Classification techniques on the required features
#
# Do you think you are on track with your project? If not, what parts do you need to dedicate more time to?
# 1. Not really, because we're lagging behind in implementation of ML techniques for predicting various Health Outcomes.
#
# Given your initial exploration of the data, is it worth proceeding with your
# project, why? If not, how are you going to change your project and why do you think it’s better than your current results?
# 1. Yes, because it has a social impact and the data we have is large and sufficient enough to come up with a concrete result which will assist in planning for better public health interventions.

# %% [markdown]
# # Next Steps

# %% [markdown]
# 1. We plant to apply ML techniques on the datasets we have finalised to predict Health Outcomes for specific geographic locations.
# 2. We also plan to correlate the Income and Health Outcomes to Timely nd Effective care services provided by the hospitals for specific geographic locations.

# %% [markdown]
# # Link to Jupyter Notebook

# %% [markdown]
# https://github.com/edgeslab/cs418-project-the-a-team/blob/master/Project%20Progress%20Report.ipynb
